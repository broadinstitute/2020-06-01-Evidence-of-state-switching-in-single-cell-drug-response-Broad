# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
import plotnine as gg
import umap
from pathlib import Path
import scipy.linalg
from sklearn.feature_selection import VarianceThreshold
from functions_utils import *

# %%
outpath = Path(os.path.join("..", "Figures"))
outpath
# Out:
# PosixPath('../Figures')

# %% [markdown]
# ## loading data

# %%
top_dir = os.path.dirname(os.getcwd())
proj_dir = 'data'


class load_data:
    
    
    def __init__(self,top_dir,proj_dir):
        
        self.top_dir = top_dir
        self.proj_dir = proj_dir
    
    
    def csvpath(self):
        path = os.path.join(self.top_dir, self.proj_dir, "backend")
        plates = [pl for pl in os.listdir(path)]
        csvpath = [os.path.join(path, pl, pl + "_dmso.csv") for pl in plates]  
        
        return csvpath

    
    def featlist(self):
        path = os.path.join(self.top_dir, self.proj_dir,"metadata","input", "feature_list.txt")
        featlist = np.loadtxt(str(path), dtype=str).tolist()
        return featlist

    
    
    
    
subclass = load_data(top_dir, proj_dir)

csvlist = subclass.csvpath()

featlist = subclass.featlist()


csvlist
# Out:
# ['/Users/habbasi/Documents/Github/broadinstitute/2020-06-01-Evidence-of-state-switching-in-single-cell-drug-response-Broad/data/backend/SQ00015142/SQ00015142_dmso.csv',
#  '/Users/habbasi/Documents/Github/broadinstitute/2020-06-01-Evidence-of-state-switching-in-single-cell-drug-response-Broad/data/backend/SQ00015145/SQ00015145_dmso.csv',
#  '/Users/habbasi/Documents/Github/broadinstitute/2020-06-01-Evidence-of-state-switching-in-single-cell-drug-response-Broad/data/backend/SQ00015144/SQ00015144_dmso.csv',
#  '/Users/habbasi/Documents/Github/broadinstitute/2020-06-01-Evidence-of-state-switching-in-single-cell-drug-response-Broad/data/backend/SQ00015143/SQ00015143_dmso.csv',
#  '/Users/habbasi/Documents/Github/broadinstitute/2020-06-01-Evidence-of-state-switching-in-single-cell-drug-response-Broad/data/backend/SQ00015201/SQ00015201_dmso.csv']

# %% [markdown]
# ## Data Preprocessing

# %%
def processing_data(csvlist, featlist, outdata):
    
    """
    Implements the combining CSV's, zscoring, whitening and umap
    
    Arguments:
    
    csvlist -- input list of dataset path
    
    featlist -- list of pre-selected features
    
    outdata -- returns output data
    
    parameters:
                "combined" -- returns z-normalized combined CSV's profiles
                "combined+umap" -- returns umap of z-normalized combined CSV's profiles
                "combined+whitened" -- returns whitened z-normalized combined CSV's profiles
                "combined+whitened+umap" -- returns umap of whitened z-normalized combined CSV's profiles
                    
                       
    
    Returns:
    
    outdata  -- combined DataFrame
    
    """
    
    
    combined = []
    
    for csv in csvlist:
        
        metadata = ['Image_FileName_OrigMito', 'Image_FileName_OrigER', 'Image_PathName_OrigER', 
                    'Metadata_mg_per_ml','Image_PathName_OrigDNA','Image_PathName_OrigRNA',
                    'Image_PathName_OrigMito','Image_FileName_OrigDNA','Image_FileName_OrigRNA',
                    'Metadata_broad_sample','Image_Metadata_Well','Metadata_plate_map_name',
                    'Metadata_mmoles_per_liter','Image_FileName_CellOutlines','Image_Metadata_Site',
                    'Metadata_Plate','Image_FileName_OrigAGP','Image_PathName_CellOutlines',
                    'Image_PathName_OrigAGP','Cells_Location_Center_X','Cells_Location_Center_Y',
                    'Nuclei_Location_Center_X','Nuclei_Location_Center_Y','Cytoplasm_Location_Center_X', 
                    'Cytoplasm_Location_Center_Y','ObjectNumber']
        
    
        dmso = pd.read_csv(csv)
        
        scale = StandardScaler()
        
        scaled_data = scale.fit_transform(dmso[featlist].values)
        
         
        
        
        if outdata == "combined":
            
             
            df = dmso[metadata].merge(pd.DataFrame(scaled_data, columns=featlist), 
                                            how='left',
                                            left_index=True,
                                            right_index=True
                                           )
            
            combined.append(df)
            
            
            
            
        elif outdata == "combined+umap":
            
            
            reducer = umap.UMAP(random_state=42)
        
            embedding = reducer.fit_transform(scaled_data)
        
            test = pd.DataFrame(embedding, columns= ['UMAP-1', 'UMAP-2'])
            
            df = dmso[metadata].merge(test, how='left',
                                            left_index=True,
                                            right_index=True)
            

            combined.append(df)
            
            
        elif outdata == "combined+whitened":
            
            
            dmso_mean = np.mean(scaled_data, axis=0)

        ## Applying whitening transformation on Z normalized features
            
            REG_PARAM = 1e-6

            AW = whitening_transform(scaled_data - dmso_mean, REG_PARAM, rotate=False)
    
            wh_profile = whiten(scaled_data, dmso_mean, AW)
             
            df = dmso[metadata].merge(pd.DataFrame(wh_profile, columns=featlist), 
                                            how='left',
                                            left_index=True,
                                            right_index=True
                                           )
            
            
            combined.append(df)
            
            
        elif outdata == "combined+whitened+umap"
      
            
            dmso_mean = np.mean(scaled_data, axis=0)
            
            REG_PARAM = 1e-6

            AW = whitening_transform(scaled_data - dmso_mean, REG_PARAM, rotate=False)
    
            wh_profile = whiten(scaled_data, dmso_mean, AW)
         
            reducer = umap.UMAP(random_state=42)
        
            embedding = reducer.fit_transform(wh_profile)
        
            test = pd.DataFrame(embedding, columns= ['UMAP-1', 'UMAP-2'])
            
            df = dmso[metadata].merge(test, how='left',
                                            left_index=True,
                                            right_index=True)
            
            
            combined.append(df)
        
    
    return pd.concat(combined)


# combined_csv = processing_data(csvlist, featlist, do_umap=False)
#combined_umap = processing_data(csvlist, featlist, do_umap=True)
    
#df_whitened = processing_data(csvlist, featlist, do_whitening=True)

df_whitened_umap = processing_data(csvlist, featlist, do_umap_whiten=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-89-80c8a8e7c5a8> in <module>
#     144 #df_whitened = processing_data(csvlist, featlist, do_whitening=True)
#     145
# --> 146 df_whitened_umap = processing_data(csvlist, featlist, do_umap = False, do_umap_whiten=True)
#
# <ipython-input-89-80c8a8e7c5a8> in processing_data(csvlist, featlist, do_umap, do_umap_whiten)
#      39
#      40
# ---> 41         dmso = pd.read_csv(csv)
#      42
#      43
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/common.py in is_categorical_dtype(arr_or_dtype)
#     540
#     541
# --> 542 def is_categorical_dtype(arr_or_dtype) -> bool:
#     543     """
#     544     Check whether an array-like or dtype is of the Categorical dtype.
#
# KeyboardInterrupt:

# %%
df_whitened_umap.head()
# Out:
#           Image_FileName_OrigMito           Image_FileName_OrigER  \
# 0  r01c01f01p01-ch5sk1fk1fl1.tiff  r01c01f01p01-ch2sk1fk1fl1.tiff
# 1  r01c01f01p01-ch5sk1fk1fl1.tiff  r01c01f01p01-ch2sk1fk1fl1.tiff
# 2  r01c01f01p01-ch5sk1fk1fl1.tiff  r01c01f01p01-ch2sk1fk1fl1.tiff
# 3  r01c01f01p01-ch5sk1fk1fl1.tiff  r01c01f01p01-ch2sk1fk1fl1.tiff
# 4  r01c01f01p01-ch5sk1fk1fl1.tiff  r01c01f01p01-ch2sk1fk1fl1.tiff
#
#                                Image_PathName_OrigER  Metadata_mg_per_ml  \
# 0  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...                 NaN
# 1  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...                 NaN
# 2  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...                 NaN
# 3  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...                 NaN
# 4  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...                 NaN
#
#                               Image_PathName_OrigDNA  \
# 0  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 1  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 2  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 3  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 4  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
#
#                               Image_PathName_OrigRNA  \
# 0  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 1  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 2  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 3  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 4  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
#
#                              Image_PathName_OrigMito  \
# 0  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 1  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 2  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 3  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 4  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
#
#            Image_FileName_OrigDNA          Image_FileName_OrigRNA  \
# 0  r01c01f01p01-ch1sk1fk1fl1.tiff  r01c01f01p01-ch3sk1fk1fl1.tiff
# 1  r01c01f01p01-ch1sk1fk1fl1.tiff  r01c01f01p01-ch3sk1fk1fl1.tiff
# 2  r01c01f01p01-ch1sk1fk1fl1.tiff  r01c01f01p01-ch3sk1fk1fl1.tiff
# 3  r01c01f01p01-ch1sk1fk1fl1.tiff  r01c01f01p01-ch3sk1fk1fl1.tiff
# 4  r01c01f01p01-ch1sk1fk1fl1.tiff  r01c01f01p01-ch3sk1fk1fl1.tiff
#
#   Metadata_broad_sample  ... Nuclei_Texture_DifferenceVariance_RNA_20_0  \
# 0                  DMSO  ...                                   0.582124
# 1                  DMSO  ...                                   0.390853
# 2                  DMSO  ...                                  -0.956617
# 3                  DMSO  ...                                  -0.079955
# 4                  DMSO  ...                                   0.798430
#
#   Cytoplasm_Granularity_2_RNA  Nuclei_Texture_Variance_Mito_10_0  \
# 0                   -0.154323                          -1.536069
# 1                    0.139205                          -1.532026
# 2                    1.531959                          -1.456381
# 3                   -0.907329                           0.581256
# 4                   -0.938615                           0.401861
#
#   Cells_Intensity_MassDisplacement_AGP  \
# 0                             1.288666
# 1                             0.715597
# 2                            -0.531671
# 3                             0.017111
# 4                             0.614132
#
#    Nuclei_RadialDistribution_RadialCV_ER_2of4  \
# 0                                    0.614540
# 1                                   -0.625499
# 2                                   -0.130123
# 3                                   -0.676401
# 4                                    2.092045
#
#   Cytoplasm_Intensity_MaxIntensity_AGP  \
# 0                             1.010505
# 1                             0.385490
# 2                             0.432410
# 3                             1.033669
# 4                            -0.508381
#
#   Nuclei_Texture_DifferenceEntropy_AGP_20_0  \
# 0                                  2.164511
# 1                                 -1.003457
# 2                                  0.157793
# 3                                  0.522308
# 4                                 -0.588939
#
#   Cytoplasm_Texture_InfoMeas1_RNA_10_0 UMAP-1  UMAP-2
# 0                            -1.266609    NaN     NaN
# 1                             0.722429    NaN     NaN
# 2                            -0.323293    NaN     NaN
# 3                            -0.594011    NaN     NaN
# 4                             0.006959    NaN     NaN
#
# [5 rows x 807 columns]

# %%
def plotting_function(data, title, filename, outpath):
    
    p = gg.ggplot(data, gg.aes(x='UMAP-1', y='UMAP-2', color= 'Metadata_Plate')) + \
    gg.geom_point(size = 0.003) + \
    gg.xlab("UMAP-1") + \
    gg.ylab("UMAP-2") + \
    gg.ggtitle(title) + \
    gg.theme_bw() 

   
    gg.ggsave(filename=filename, plot = p, path = outpath)

    
    return p

# %%
plotting_function(df_whitened_umap, "UMAP of DMSO-whitened cellprofiles", "UMAP_DMSO-whitened_cellprofiles.csv", outpath)
# Out:
# /Users/habbasi/plotnine/plotnine/ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /Users/habbasi/plotnine/plotnine/ggplot.py:730: PlotnineWarning: Filename: ../Figures/UMAP_DMSO-whitened_cellprofiles.csv
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/plotnine/plotnine/layer.py in compute_aesthetics(self, plot)
#     320                     try:
# --> 321                         new_val = env.eval(col, inner_namespace=data)
#     322                     except Exception as e:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/patsy/eval.py in eval(self, expr, source_name, inner_namespace)
#     165         return eval(code, {}, VarLookupDict([inner_namespace]
# --> 166                                             + self._namespaces))
#     167
#
# <string> in <module>
#
# NameError: name 'UMAP' is not defined
#
# During handling of the above exception, another exception occurred:
#
# PlotnineError                             Traceback (most recent call last)
# <ipython-input-66-8d234582f4f4> in <module>
# ----> 1 plotting_function(df_whitened_umap, "UMAP of DMSO-whitened cellprofiles", "UMAP_DMSO-whitened_cellprofiles.csv", outpath)
#
# <ipython-input-65-6c0eabf044ed> in plotting_function(data, title, filename, outpath)
#       9
#      10
# ---> 11     gg.ggsave(filename=filename, plot = p, path = outpath)
#      12
#      13
#
# ~/plotnine/plotnine/ggplot.py in ggsave(plot, *arg, **kwargs)
#     759     Use :meth:`ggplot.save` instead
#     760     """
# --> 761     return plot.save(*arg, **kwargs)
#     762
#     763
#
# ~/plotnine/plotnine/ggplot.py in save(self, filename, format, path, width, height, units, dpi, limitsize, verbose, **kwargs)
#     748         except Exception as err:
#     749             figure[0] and plt.close(figure[0])
# --> 750             raise err
#     751         else:
#     752             figure[0] and plt.close(figure[0])
#
# ~/plotnine/plotnine/ggplot.py in save(self, filename, format, path, width, height, units, dpi, limitsize, verbose, **kwargs)
#     745
#     746         try:
# --> 747             _save()
#     748         except Exception as err:
#     749             figure[0] and plt.close(figure[0])
#
# ~/plotnine/plotnine/ggplot.py in _save()
#     732         # Helper function so that we can clean up when it fails
#     733         def _save():
# --> 734             fig = figure[0] = self.draw()
#     735
#     736             # savefig ignores the figure face & edge colors
#
# ~/plotnine/plotnine/ggplot.py in draw(self, return_ggplot)
#     179         # new frames knowing that they are separate from the original.
#     180         with pd.option_context('mode.chained_assignment', None):
# --> 181             return self._draw(return_ggplot)
#     182
#     183     def _draw(self, return_ggplot=False):
#
# ~/plotnine/plotnine/ggplot.py in _draw(self, return_ggplot)
#     186         # assign a default theme
#     187         self = deepcopy(self)
# --> 188         self._build()
#     189
#     190         # If no theme we use the default
#
# ~/plotnine/plotnine/ggplot.py in _build(self)
#     286         # Compute aesthetics to produce data with generalised
#     287         # variable names
# --> 288         layers.compute_aesthetics(self)
#     289
#     290         # Transform data using all scales
#
# ~/plotnine/plotnine/layer.py in compute_aesthetics(self, plot)
#      79     def compute_aesthetics(self, plot):
#      80         for l in self:
# ---> 81             l.compute_aesthetics(plot)
#      82
#      83     def compute_statistic(self, layout):
#
# ~/plotnine/plotnine/layer.py in compute_aesthetics(self, plot)
#     322                     except Exception as e:
#     323                         raise PlotnineError(
# --> 324                             _TPL_EVAL_FAIL.format(ae, col, str(e)))
#     325
#     326                     try:
#
# PlotnineError: "Could not evaluate the 'x' mapping: 'UMAP-1' (original error: name 'UMAP' is not defined)"
